# %%
import json

# %%
with open('resources/natasha.json') as s:
    natasha = json.load(s)
    pers_natasha = set(k for i in natasha.values() for j in i['pers'] for k in j.split())
    locs_natasha = set(k for i in natasha.values() for j in i['locs'] for k in j.split())

with open('resources/deeppavlov.json') as s:
    deeppavlov = json.load(s)
    pers_natasha = set(k for i in deeppavlov.values() for j in i['pers'] for k in j.split())
    locs_natasha = set(k for i in deeppavlov.values() for j in i['locs'] for k in j.split())

with open('resources/spacy.json') as s:
    spacy = json.load(s)
    pers_natasha = set(k for i in spacy.values() for j in i['pers'] for k in j.split())
    locs_natasha = set(k for i in spacy.values() for j in i['locs'] for k in j.split())

with open('resources/stanza.json') as s:
    stanza = json.load(s)
    pers_natasha = set(k for i in stanza.values() for j in i['pers'] for k in j.split())
    locs_natasha = set(k for i in stanza.values() for j in i['locs'] for k in j.split())

with open('resources/transformers.json') as s:
    transformers = json.load(s)
    pers_natasha = set(k for i in transformers.values() for j in i['pers'] for k in j.split())
    locs_natasha = set(k for i in transformers.values() for j in i['locs'] for k in j.split())

# %%
pers_all = 
locs_all = 

print(pers_natasha)
print(locs_natasha)
# Out:
# {'Азатовичем', 'Фаерман', 'Алины', 'Рудольфовнаа', 'н', 'православная', 'mariya', 'Ивочкин', 'Борисович', 'Красковский', 'сауне', 'Рудольфовича', 'Камо', 'Сергеевича', 'ЦТИ', 'Дорин', 'Сего', 'ШАЛЯПИНА', 'Кемпбелл', 'Демин', 'Викторовна', 'Юрьевны', 'Калюжина', 'гре', 'Владимировича', 'Шамсиев', 'Тета', 'Мельницын', 'Фоатовичем', 'Насхатовичем', 'Кирсанова', 'ВАРЛАМОВ', 'Ларцина', 'Ильдусовна', 'letovderevne', 'Сошников', 'Богородицы', 'Золина', 'Валентиновичем', 'Новожилова', 'Саенко', 'Айгуль', 'Тамарой', '.', 'Дзюбенко', 'Заречнева', 'Юрьевичем', 'saratov', 'Садыка', 'Кашицын', 'Аболемова', 'Ахатович', 'ея', 'Рафаэлевич', 'Викторовны', 'Заи', 'Тамерлан', 'ЛЕНИНГРАДСКАЯ', 'Мариeй', 'Азимова', 'Ивановича', 'батьки', 'сита', 'дортмундская', 'Алмазович', 'Руси', 'Александровной', 'Горленко', 'Азат', 'Альбиной', 'Доронина', 'Анатольевна', 'Топильский', 'Балахнинское', 'Земскова', 'Ахраменко', 'Александры', 'Петровна', 'лами', 'ОГУП', 'Локтионов', 'АЛЕКСЕЕВИЧ', 'Витальевна', 'луне', 'Ар
# ...
